# %% [markdown]
# Joinplot y Pairplot
#
# https://seaborn.pydata.org/generated/seaborn.jointplot.html
# https://seaborn.pydata.org/generated/seaborn.pairplot.html

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
sns.jointplot(data=tips, x='total_bill', y='tip',hue='sex',kind='hist')

# %%
sns.jointplot(data=tips, x='total_bill', y='tip',hue='sex',kind='hist',marginal_ticks=True,
marginal_kws=dict(bins=25,fill=False,multiple='dodge'),height=10)

# %%
sns.pairplot(data=tips,height=5);

# %%
sns.pairplot(data=tips,height=5,hue='sex');

# %%
sns.pairplot(data=tips,height=5,hue='sex',palette='pastel');

# %%
sns.pairplot(data=tips,hue='sex',palette='coolwarm',corner=True,kind='scatter');
