# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,'ro')

# %%
plt.plot(x,y,'y')

# %%
plt.plot(x,y,'yx')
